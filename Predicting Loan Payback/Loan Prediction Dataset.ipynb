# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#annual_income - Годовой доход заемщика
#debt_to_income_ratio - Отношение займ/доход для заемщика	
#credit_score - Кредитный рейтинг (больше значение-меньше риска)
#loan_amount - Размер займа
#interest_rate - Годовая процентная ставка по кредиту
#gender	- Пол заемщика ['Female','Male','Other']
#marital_status	- Семейное положение ['Single','Married','Divorced','Widowed']
#education_level - Образование ['High School',"Master's","Bachelor's",'PhD','Other']
#employment_status - Текущий тип занятости ['Self-employed','Employed','Unemployed','Retired','Student']
#loan_purpose - На что взятт займ ['Other','Debt consolidation','Home','Education','Vacation','Car','Medical','Business']
#grade_subgrade - Риск займа
#loan_paid_back - 1-выплатил, 2-не выплатил полностью

# %%
#Загрузка данных
df_train_origin = pd.read_csv('train.csv', index_col='id')
df_test_origin = pd.read_csv('test.csv', index_col='id')
df_full = pd.concat([df_train_origin, df_test_origin], axis=0)
